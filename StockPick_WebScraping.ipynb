# %% [markdown]
# <a href="https://colab.research.google.com/github/Manasi200/Stock-price-prediction/blob/main/StockPick_WebScraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Stock Price Prediction using a web-scraper**
#
# ---

# %% [markdown]
# ![sp-1.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Python Beautiful Soup

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://finance.yahoo.com/quote/AAPL?p=AAPL"

# %%
response = requests.get(url)

print(response)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'lxml')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
stock = soup.find_all('div', {'class' : "My(6px) Pos(r) smartphone_Mt(6px) W(100%) "})[0].find().text

# %%
 print(stock)
# Out:
# 153.07-1.02 (-0.66%)As of  10:48AM EDT. Market open.

# %%
print('Current Price : ' + stock)
# Out:
# Current Price : 153.07-1.02 (-0.66%)As of  10:48AM EDT. Market open.
